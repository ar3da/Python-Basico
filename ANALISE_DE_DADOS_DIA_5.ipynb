# %% [markdown]
# <a href="https://colab.research.google.com/github/ar3da/Python-Basico/blob/main/ANALISE_DE_DADOS_DIA_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt


#Exemplos de notas de alunos

dados = {
    "Alunos": ["Ana", "Bruno", "Daniela", "Eduardo", "Fernanda"],
    "Notas": [8, 7.5, 9, 6, 7]
}

df= pd.DataFrame(dados)

print(df)
# Out:
#      Alunos  Notas
# 0       Ana    8.0
# 1     Bruno    7.5
# 2   Daniela    9.0
# 3   Eduardo    6.0
# 4  Fernanda    7.0

# %%
#Criando um gráfico de barras

plt.bar(df["Alunos"], df["Notas"])
plt.xlabel("Alunos")
plt.ylabel("Notas")
plt.title("Notas dos Alunos")
plt.show()

# %%
#Criando gráficos de linhas

plt.plot(df["Alunos"], df["Notas"])
plt.xlabel("Alunos")
plt.ylabel("Notas")
plt.title("Notas dos Alunos")
plt.show()

# %%
#Criando gráfico de pizza

plt.pie(df["Notas"], labels=df["Alunos"])
plt.title("Notas dos Alunos")
plt.show()

# %%
#Exercicio dia 5: Criar gráficos usando dados de vendas

dados = {
    'Produto': ['Caderno', 'Caneta', 'Lápis', 'Borracha'],
    'Vendas': [120, 200, 150, 90]
}

df = pd.DataFrame(dados)

print(df)

plt.bar(df["Produto"], df["Vendas"])
plt.xlabel("Produto")
plt.ylabel("Vendas")
plt.title("Vendas dos Produtos")
plt.show()

print("_"*40)

plt.plot(df["Produto"], df["Vendas"])
plt.xlabel("Produto")
plt.ylabel("Vendas")
plt.title("Vendas dos Produtos")
plt.show()

print("_"*40)

plt.pie(df["Vendas"], labels=df["Produto"])
plt.title("Vendas dos Produtos")
plt.show()
# Out:
#     Produto  Vendas
# 0   Caderno     120
# 1    Caneta     200
# 2     Lápis     150
# 3  Borracha      90
# ________________________________________
# ________________________________________
